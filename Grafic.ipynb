# %%
x = [0.54545, 0.54662, 0.53032, 0.22987, 0.59685]

# %%
y = [5, 5, 5, 5, 5]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize= (8,8))
plt.scatter( x, y)
plt.xlabel('Score')
plt.ylabel('k')
plt.show()
